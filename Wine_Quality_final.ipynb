# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns


from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# # Loading Dataset

# %%
wine = pd.read_csv("winequality-red.csv")
print("Successfully Imported Data!")
wine.head()
# Out:
# Successfully Imported Data!
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   11                    34   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
print(wine.shape)
# Out:
# (299, 12)

# %% [markdown]
# # Description

# %%
wine.describe(include='all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     299.000000        299.000000   299.000000      299.000000
# mean        7.998997          0.551940     0.235251        2.439130
# std         1.508866          0.180352     0.193275        1.164761
# min         4.600000          0.180000     0.000000        1.200000
# 25%         7.200000          0.420000     0.070000        1.800000
# 50%         7.800000          0.550000     0.200000        2.000000
# 75%         8.400000          0.645000     0.360000        2.500000
# max        15.000000          1.330000     1.000000       10.700000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  299.000000           299.000000            299.000000  299.000000
# mean     0.098227            15.153846             56.461538    0.996937
# std      0.072434             9.092538             35.709506    0.001374
# min      0.039000             3.000000              8.000000    0.991600
# 25%      0.073000             9.000000             28.000000    0.996200
# 50%      0.081000            13.000000             47.000000    0.996800
# 75%      0.093000            19.000000             73.000000    0.997600
# max      0.611000            52.000000            153.000000    1.001400
#
#                pH   sulphates     alcohol     quality
# count  299.000000  299.000000  299.000000  299.000000
# mean     3.325552    0.690234    9.878595    5.408027
# std      0.155017    0.242937    0.815420    0.724038
# min      2.740000    0.330000    9.000000    4.000000
# 25%      3.220000    0.550000    9.400000    5.000000
# 50%      3.340000    0.610000    9.600000    5.000000
# 75%      3.410000    0.770000   10.200000    6.000000
# max      3.900000    2.000000   14.000000    8.000000

# %% [markdown]
# # Finding Null Values

# %%
print(wine.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.345975     0.548114
# volatile acidity          -0.345975          1.000000    -0.560263
# citric acid                0.548114         -0.560263     1.000000
# residual sugar             0.092418         -0.100091     0.123835
# chlorides                  0.064731         -0.048668     0.353849
# free sulfur dioxide       -0.044114         -0.039963     0.103321
# total sulfur dioxide      -0.125037          0.018024     0.170079
# density                    0.705809         -0.220937     0.401988
# pH                        -0.583977          0.203986    -0.464859
# sulphates                  0.245344         -0.207760     0.375962
# alcohol                   -0.088959         -0.078896     0.005144
# quality                    0.269760         -0.360845     0.115329
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.092418   0.064731            -0.044114
# volatile acidity           -0.100091  -0.048668            -0.039963
# citric acid                 0.123835   0.353849             0.103321
# residual sugar              1.000000  -0.049148             0.257572
# chlorides                  -0.049148   1.000000             0.091715
# free sulfur dioxide         0.257572   0.091715             1.000000
# total sulfur dioxide        0.204958   0.063602             0.726390
# density                     0.400504   0.114483             0.040072
# pH                          0.033120  -0.418636            -0.120314
# sulphates                   0.013084   0.550074             0.124646
# alcohol                     0.128539  -0.158208            -0.010281
# quality                     0.054220  -0.093594            -0.114571
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.125037  0.705809 -0.583977   0.245344
# volatile acidity                  0.018024 -0.220937  0.203986  -0.207760
# citric acid                       0.170079  0.401988 -0.464859   0.375962
# residual sugar                    0.204958  0.400504  0.033120   0.013084
# chlorides                         0.063602  0.114483 -0.418636   0.550074
# free sulfur dioxide               0.726390  0.040072 -0.120314   0.124646
# total sulfur dioxide              1.000000 -0.076778 -0.197597   0.163027
# density                          -0.076778  1.000000 -0.314936   0.249020
# pH                               -0.197597 -0.314936  1.000000  -0.472712
# sulphates                         0.163027  0.249020 -0.472712   1.000000
# alcohol                          -0.027975 -0.333178  0.351504   0.007005
# quality                          -0.249365  0.095382  0.007854   0.104765
#
#                        alcohol   quality
# fixed acidity        -0.088959  0.269760
# volatile acidity     -0.078896 -0.360845
# citric acid           0.005144  0.115329
# residual sugar        0.128539  0.054220
# chlorides            -0.158208 -0.093594
# free sulfur dioxide  -0.010281 -0.114571
# total sulfur dioxide -0.027975 -0.249365
# density              -0.333178  0.095382
# pH                    0.351504  0.007854
# sulphates             0.007005  0.104765
# alcohol               1.000000  0.304718
# quality               0.304718  1.000000

# %%
wine.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 4             7.366667          0.758333     0.177333        2.220000
# 5             7.802907          0.575349     0.235640        2.455233
# 6             8.114607          0.510000     0.213933        2.392135
# 7             9.461905          0.411190     0.342857        2.419048
# 8             9.100000          0.335000     0.455000        5.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 4         0.116933            16.266667             50.600000  0.996537
# 5         0.101797            15.796512             65.761628  0.996903
# 6         0.090899            14.516854             44.359551  0.996963
# 7         0.088857            12.285714             38.761905  0.997338
# 8         0.075500            10.000000             25.000000  0.997450
#
#                pH  sulphates    alcohol
# quality
# 4        3.378000   0.692667   9.846667
# 5        3.312151   0.671919   9.702326
# 6        3.347079   0.701461  10.037079
# 7        3.310000   0.776667  10.404762
# 8        3.290000   0.840000  12.700000

# %% [markdown]
# ## KDE plot:

# %%
sns.kdeplot(wine.query('quality > 2').quality)
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %% [markdown]
# ## Distplot:

# %%
sns.distplot(wine['alcohol'])

# %%
wine.plot(kind ='density',subplots = True, layout =(4,4),sharex = False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %% [markdown]
# ## Histogram

# %%
wine.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# # Heatmap for expressing correlation

# %%
corr = wine.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Feature Selection

# %%
# Create Classification version of target variable
wine['goodquality'] = [1 if x >= 7 else 0 for x in wine['quality']]# Separate feature variables and target variable
X = wine.drop(['quality','goodquality'], axis = 1)
Y = wine['goodquality']

# %%
# See proportion of good vs bad wines
wine['goodquality'].value_counts()
# Out:
# goodquality
# 0    276
# 1     23
# Name: count, dtype: int64

# %%
X
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 294           13.3              0.34         0.52             3.2      0.094
# 295           10.8              0.50         0.46             2.5      0.073
# 296           10.6              0.83         0.37             2.6      0.086
# 297            7.1              0.63         0.06             2.0      0.083
# 298            7.2              0.65         0.02             2.3      0.094
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                     11                    34  0.99780  3.51       0.56
# 1                     25                    67  0.99680  3.20       0.68
# 2                     15                    54  0.99700  3.26       0.65
# 3                     17                    60  0.99800  3.16       0.58
# 4                     11                    34  0.99780  3.51       0.56
# ..                   ...                   ...      ...   ...        ...
# 294                   17                    53  1.00140  3.05       0.81
# 295                    5                    27  1.00010  3.05       0.64
# 296                   26                    70  0.99810  3.16       0.52
# 297                    8                    29  0.99855  3.67       0.73
# 298                    5                    31  0.99930  3.67       0.80
#
#      alcohol
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
# ..       ...
# 294      9.5
# 295      9.5
# 296      9.9
# 297      9.6
# 298      9.7
#
# [299 rows x 11 columns]

# %%
print(Y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: goodquality, Length: 299, dtype: int64

# %% [markdown]
# # Feature Importance

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

from sklearn.ensemble import ExtraTreesClassifier
classifiern = ExtraTreesClassifier()
classifiern.fit(X,Y)
score = classifiern.feature_importances_
print(score)
# Out:
# [0.12130444 0.11253253 0.08227973 0.09800252 0.06878394 0.07468291
#  0.0768448  0.07948522 0.06597601 0.098796   0.1213119 ]

# %% [markdown]
# # Splitting Dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %% [markdown]
# # LogisticRegression:

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy Score:",accuracy_score(Y_test,Y_pred)*100)
# Out:
# Accuracy Score: 93.33333333333333

# %%
confusion_mat = confusion_matrix(Y_test,Y_pred)
print(confusion_mat)
# Out:
# [[81  0]
#  [ 6  3]]

# %% [markdown]
# # Using KNN:

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred)*100)
# Out:
# Accuracy Score: 91.11111111111111

# %% [markdown]
# # Using Decision Tree:

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=5)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred)*100)
# Out:
# Accuracy Score: 90.0

# %% [markdown]
# # Using Random Forest:

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=8)
model2.fit(X_train, Y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred2)*100)
# Out:
# Accuracy Score: 93.33333333333333

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','KNN','Decision Tree' ,'Random Forest'],
    'Score': [93.33,91.11,90.0,93.33]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df
# Out:
#                      Model
# Score
# 93.33  Logistic Regression
# 93.33        Random Forest
# 91.11                  KNN
# 90.00        Decision Tree

# %%
#Hence I will use Random Forest and logistic regression algorithms for training my model.
